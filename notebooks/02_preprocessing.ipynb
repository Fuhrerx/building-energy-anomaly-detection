# %% [markdown]
# # Data Preprocessing of our Explored data

# %% [markdown]
# ## What we did so far
#
# We explored our data last time with key inferences obtained from our data, we also joined 8 of the datasets we have on data/meters/raw folder, from this we found that the final consolidated data has 8 rows and 1600+ columns that can be cleaned and preprocessed here.
#
# The timestamp column requires cleaning and as well as other columns so we could extract key insights from this dataset

# %% [markdown]
# ## Importing Libraries

# %%
import os
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
df = pd.read_csv(r"C:\Users\Akshay\Desktop\building-energy-anomaly-detection\data\meters\whole\eda.csv")

# %% [markdown]
# ## Cleaning Data

# %%
df['timestamp'] = pd.to_datetime(df['timestamp']) 
df = df.sort_values('timestamp')  

# Filling missing values using forward fill and backward fills

df = df.ffill().bfill()

# %%
# Capping the data to remove outliers using 1st and 99th percentiles

for col in df.columns: 
    if col != 'timestamp': 
        lower = df[col].quantile(0.01)
        upper = df[col].quantile(0.99)
        df[col] = df[col].clip(lower=lower, upper=upper)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Capping the data to remove outliers using 1st and 99th percentiles
# ----> 3 for col in df.columns:
#       4     if col != 'timestamp':
#       5         lower = df[col].quantile(0.01)
#
# NameError: name 'df' is not defined
